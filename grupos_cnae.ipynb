# %% [markdown]
# # Fazendo similaridade de acordo com os grupos separados de CNAE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
jardim = pd.read_csv('/content/drive/MyDrive/Projetos_ion/ION_Smart_Locator/datasets/CNPJ_metadados/bairro_jardim_geolocalizado.csv')
jardim.head()
# Out:
#                  cnpj identificador_matriz_filial          nome_fantasia  \
# 0  37.392.382/0001-56                      MATRIZ                    NaN
# 1  40.035.426/0001-03                      MATRIZ          GARAGE'S FOOD
# 2  41.106.369/0001-60                      MATRIZ   PIZZARIA DA LINDAURA
# 3  42.665.147/0001-40                      MATRIZ  EBENEZER A&V PINTURAS
# 4  44.080.036/0001-06                      MATRIZ            ACAI DRINKS
#
#    pais  data_inicio_atividade  \
# 0   NaN               20200612
# 1   NaN               20201207
# 2   NaN               20210305
# 3   NaN               20210711
# 4   NaN               20211030
#
#                                cnae_fiscal_principal cnae_fiscal_secundaria  \
# 0                         Serviços de entrega rápida                    NaN
# 1                           Restaurantes e similares                5611203
# 2  Serviços de alimentação para eventos e recepçõ...                    NaN
# ...

# %%
jardim[jardim['cnae_fiscal_principal'] == 'Serviços de pintura de edifícios em geral']
# Out:
#                    cnpj identificador_matriz_filial           nome_fantasia  \
# 3    42.665.147/0001-40                      MATRIZ   EBENEZER A&V PINTURAS
# 124  42.446.531/0001-52                      MATRIZ              JD PINTURA
# 178  26.690.159/0001-79                      MATRIZ  BH PINTURAS E REFORMAS
#
#      pais  data_inicio_atividade                      cnae_fiscal_principal  \
# 3     NaN               20210711  Serviços de pintura de edifícios em geral
# 124   NaN               20210623  Serviços de pintura de edifícios em geral
# 178   NaN               20161209  Serviços de pintura de edifícios em geral
#
#     cnae_fiscal_secundaria tipo_logradouro  logradouro numero  ...  ddd1  \
# 3                  4741500             RUA     CURVELO    315  ...  31.0
# 124                2539002         AVENIDA  OURO VERDE      7  ...  31.0
# 178                4330405             RUA  MONTE SIAO    169  ...  31.0
#
# ...
