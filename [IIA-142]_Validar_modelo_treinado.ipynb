# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Projetos_ion/ION_Prospeccao_Inteligente/datasets/Tupan/dataset_limpo_tupan_filial1.csv')

df1.shape
# Out:
# (1629093, 40)

# %%
df1.target.value_counts()
# Out:
# 0    1607990
# 1      21103
# Name: target, dtype: int64

# %%
dff = pd.read_csv('/content/drive/MyDrive/Projetos_ion/ION_Prospeccao_Inteligente/datasets/Farmix/estabelecimentos_empresas_farmix_filial1_todos.csv')
dff.head()
# Out:
#                  cnpj  cnpj_basico identificador_matriz_filial  \
# 0  35.487.772/0001-84     35487772                      MATRIZ
# 1  35.506.656/0001-65     35506656                      MATRIZ
# 2  35.514.016/0001-05     35514016                      MATRIZ
# 3  35.517.447/0001-17     35517447                      MATRIZ
# 4  35.536.835/0001-45     35536835                      MATRIZ
#
#    data_inicio_atividade     cnae  \
# 0               20191112  4771701
# 1               20191113  4771701
# 2               20191114  4771701
# 3               20191114  4771701
# 4               20191118  4771701
#
#                                cnae_fiscal_principal  \
# 0  Comércio varejista de produtos farmacêuticos, ...
# 1  Comércio varejista de produtos farmacêuticos, ...
# 2  Comércio varejista de produtos farmacêuticos, ...
# 3  Comércio varejista de produtos farmacêuticos, ...
# 4  Comércio varejista de produtos farmacêuticos, ...
#
# ...

# %%
dff.uf.value_counts()
# Out:
# MG    16467
# RJ     5722
# BA     5148
# GO     1208
# SP      184
# SE       34
# SC       21
# PR       20
# RS       14
# ES       10
# PE        8
# DF        7
# AL        6
# MS        4
# AM        3
# PA        2
# PI        2
# PB        2
# TO        2
# RO        2
# CE        1
# MT        1
# Name: uf, dtype: int64

# %% [markdown]
# O que fazer: filtrar esses clientes de outro estado, pegar só de SP ou todos menos MG e testar lá no modelo pra ver se ele responde corretamente.
#
# Outra coisa é antes de testar no modelo pronto, verificar se os dados nao estão lá no dataset de treino e teste pra nao ocorrer vazamento dos dados. Testar isso com uns 2 ou 3 clientes.

# %%
teste_uf = dff[dff['uf'] != "MG"]
teste_uf.shape
# Out:
# (12401, 17)

# %%
teste_uf.head()
# Out:
#                  cnpj  cnpj_basico identificador_matriz_filial  \
# 0  35.487.772/0001-84     35487772                      MATRIZ
# 2  35.514.016/0001-05     35514016                      MATRIZ
# 4  35.536.835/0001-45     35536835                      MATRIZ
# 6  35.563.693/0001-05     35563693                      MATRIZ
# 7  34.728.300/0001-03     34728300                      MATRIZ
#
#    data_inicio_atividade     cnae  \
# 0               20191112  4771701
# 2               20191114  4771701
# 4               20191118  4771701
# 6               20191120  4771701
# 7               20190902  4771701
#
#                                cnae_fiscal_principal cnae_fiscal_secundaria  \
# 0  Comércio varejista de produtos farmacêuticos, ...                4772500
# 2  Comércio varejista de produtos farmacêuticos, ...        4772500,4773300
# 4  Comércio varejista de produtos farmacêuticos, ...        4771703,4772500
# ...

# %%
teste_uf.to_csv('/content/drive/MyDrive/Projetos_ion/ION_Prospeccao_Inteligente/datasets/Farmix/teste_uf_farmix.csv', index=False)
